# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import PMStack.Tools.helpers as helpers
import PMStack.Equity_port.portfolio as portfolio
pd.set_option('display.max_rows', 999)

start_date = pd.to_datetime('2019-12-31')

end_date = None

ignore_ticker_list = []


wb_price = 'Example historical price.xlsx'
file_price = {'workbook_name':wb_price, 'sheet_name':'Historical price'}
output_dir = 'P:\\'

wb_trades = 'Example portfolio tracking.xlsx'
file_trades = {'workbook_name':wb_trades, 'sheet_name':'US trades'}
base_currency = 'USD'
        
file_stock_info = {'workbook_name':wb_price, 'sheet_name':'Info'}

p = portfolio.Portfolio(file_price, file_trades, start_date, end_date=end_date, benchmark = 'SPX', benchmark2=['QQQ'], file_stock_info = file_stock_info, output_dir=output_dir, base_currency=base_currency, ignore_ticker_list=ignore_ticker_list)


PerfClassifiers = ['Sector']
p.printPerformanceSummary(printPerfClassifiers = PerfClassifiers)
# Out:
# Loaded price history from 2015-08-21 to 2020-12-18
#
#
# Capital unspecified. Using USD 1,054,168.60, which is beginning assets plus net deposit.
#
# ...
# For the period between 2019-12-31 and 2020-12-18
# ...
#
# Capital deployed: USD 1,054,168.60, where:
#   Beginning assets: USD 1,054,168.60
#   Net deposit: USD 0.00
#
# Total P&L: USD 522,697, or 49.58%, where:
#   Long P&L: USD 533,188, or 50.58%
#   Short P&L: USD -10,490, or -1.00%
#
# The annualized vol of the portfolio is 16.1%, while SPX and QQQ are at 34.5% and 35.7%, respectively
# The correlation with SPX and QQQ are 50.9% and 60.7%, respectively
#
# ...
# Holdings as of 2020-12-18
# ...
#
# Gross exposure: 49.7%
# Net exposure: 38.1%
#
#
# Long  book:
#        Name     Size  Weight  LastPx   PxChg SinceLatestBuy   CumPnL
# 1        SE  560,980  35.59%  200.35  398.1%         600.6%  448,364
# 2      MSFT  131,154   8.32%  218.59   38.6%          10.0%   28,119
# 3  Hua Hong        0   0.00%   47.30  166.9%         253.6%   56,832
# ...

# %%
plt.rcParams['figure.figsize'] = [16,9]

# %%
p.analyzePerfByClassfier('Sector')
# Out:
#                    Long                                               Short  \
#                    Size Avg_Exposure      TWRR            P&L          Size
# Consumer  560980.017090     0.493807  3.981353  448364.013672 -91426.499176
# Tech      131153.997803     0.242508  0.660805   84950.886510      0.000000
#
#                                                         Net
#          Avg_Exposure     TWRR           P&L           Size           P&L
# Consumer    -0.189823 -0.27143 -10490.340401  469553.517914  437873.67327
# Tech         0.000000      NaN      0.000000  131153.997803   84950.88651

# %%
#p.save_analysis_to_file()

# %%
p.printHistoricalReturns(period = 'M', periodic_benchmark_return = True)
# Out:
# Portfolio Return   Jan    Feb    Mar   Apr   May   Jun   Jul   Aug   Sep  \
# Year
# 2020              1.9%  -0.6%  -1.1%  3.8%  5.4%  9.6%  4.1%  6.8%  0.3%
#
# Portfolio Return   Oct   Nov   Dec Annual
# Year
# 2020              0.3%  6.8%  4.3%  49.6%
# SPX Return    Jan    Feb     Mar    Apr   May   Jun   Jul   Aug    Sep    Oct  \
# Year
# 2020        -0.2%  -8.4%  -12.5%  12.7%  4.5%  1.8%  5.5%  7.0%  -3.9%  -2.8%
#
# SPX Return    Nov   Dec Annual
# Year
# 2020        10.8%  2.4%  14.8%
# QQQ Return   Jan    Feb    Mar    Apr   May   Jun   Jul    Aug    Sep    Oct  \
# Year
# 2020        3.0%  -6.1%  -7.5%  15.0%  6.6%  6.1%  7.3%  10.9%  -5.8%  -3.0%
#
# QQQ Return    Nov   Dec Annual
# Year
# 2020        11.2%  3.5%  45.8%

# %%
p.plotPortfolioPnL()

# %%
p.plotPortfolioExposure()

# %%
p.plotPortfolioCapitalDeployment()
